# %%
import pandas as pd 
# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
# Control delimiters, rows, column names with read_csv (see later) 
data = pd.read_csv(r"C:\Users\topiltzin.lucero\Desktop\data-engineering-bootcamp\data\sample.csv") 
# Preview the first 5 lines of the loaded data 
data.head()
# Out:
#                   producto                                   presentacion  \
# 0  CUADERNO FORMA ITALIANA          96 HOJAS PASTA DURA. CUADRICULA CHICA
# 1                 CRAYONES              CAJA 12 CERAS. JUMBO. C.B. 201423
# 2                 CRAYONES      CAJA 12 CERAS. TAMANO REGULAR C.B. 201034
# 3        COLORES DE MADERA  CAJA 12 PIEZAS LARGO. TRIANGULAR. C.B. 640646
# 4              COLOR LARGO        CAJA 36 PIEZAS. CON SACAPUNTAS. 68-4036
#
#       marca         categoria          catalogo  precio  \
# 0  ESTRELLA  MATERIAL ESCOLAR  UTILES ESCOLARES    25.9
# 1   CRAYOLA  MATERIAL ESCOLAR  UTILES ESCOLARES    27.5
# 2   CRAYOLA  MATERIAL ESCOLAR  UTILES ESCOLARES    13.9
# 3  PINCELIN  MATERIAL ESCOLAR  UTILES ESCOLARES    46.9
# 4   CRAYOLA  MATERIAL ESCOLAR  UTILES ESCOLARES   115.0
#
#              fechaRegistro     cadenaComercial        giro  \
# 0  2011-05-18 00:00:00.000  ABASTECEDORA LUMEN  PAPELERIAS
# 1  2011-05-18 00:00:00.000  ABASTECEDORA LUMEN  PAPELERIAS
# ...

# %%
##How many commercial chains are monitored, and therefore, included in this database?

data.drop_duplicates(['cadenaComercial'])['cadenaComercial'].count()
# Out:
# 4

# %%
##What are the top 10 monitored products by State?

data_agg = data[['estado', 'producto','marca']].groupby(['estado', 'producto']).count().reset_index()

sales_sorted = data_agg.groupby(['estado']).apply(lambda x: x.sort_values(['marca'],ascending = False)).reset_index(drop = True)

# %%
data_final = sales_sorted.groupby(['estado']).head(10)

# %%
data_final
# Out:
#                estado                 producto  marca
# 0    DISTRITO FEDERAL        DETERGENTE P/ROPA     25
# 1    DISTRITO FEDERAL  LECHE ULTRAPASTEURIZADA     23
# 2    DISTRITO FEDERAL                 REFRESCO     22
# 3    DISTRITO FEDERAL           CHILES EN LATA     21
# 4    DISTRITO FEDERAL                 MAYONESA     20
# 5    DISTRITO FEDERAL                  SHAMPOO     18
# 6    DISTRITO FEDERAL              TELEVISORES     17
# 7    DISTRITO FEDERAL          GALLETAS DULCES     16
# 8    DISTRITO FEDERAL         JABON DE TOCADOR     16
# 9    DISTRITO FEDERAL              PAN DE CAJA     14
# 243            MÉXICO                 REFRESCO     26
# 244            MÉXICO        DETERGENTE P/ROPA     24
# 245            MÉXICO                  SHAMPOO     19
# 246            MÉXICO           CHILES EN LATA     18
# 247            MÉXICO          TOALLA FEMENINA     17
# 248            MÉXICO                 MAYONESA     17
# ...

# %%
##Which is the commercial chain with the highest number of monitored products?
test = data.groupby(['cadenaComercial', 'producto']).size()
test.groupby("cadenaComercial").sum().sort_values(ascending=False).head(1)
# Out:
# cadenaComercial
# COMERCIAL MEXICANA    1508
# dtype: int64

# %%
# Out:
#                estado                     producto  marca
# 0    DISTRITO FEDERAL            DETERGENTE P/ROPA     25
# 1    DISTRITO FEDERAL      LECHE ULTRAPASTEURIZADA     23
# 2    DISTRITO FEDERAL                     REFRESCO     22
# 3    DISTRITO FEDERAL               CHILES EN LATA     21
# 4    DISTRITO FEDERAL                     MAYONESA     20
# ..                ...                          ...    ...
# 541            MÉXICO                    DALACIN C      1
# 542            MÉXICO                       NESTLE      1
# 543            MÉXICO                NEO MELUBRINA      1
# 544            MÉXICO  DETERGENTE P/ROPA Y TRASTES      1
# 545            MÉXICO                       JICAMA      1
#
# [546 rows x 3 columns]

# %%
#Use the data to find an interesting fact.
